# %% [markdown]
# # HW2 - Matplotlib Exercises
#
# ***NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP.***
#
# Maximum Number of Points: 10 (2 points per question)
#
# ### Follow the instructions to recreate the plots

# %%
# Use this data for the exercises
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Question 1

# %% [markdown]
# - **Create a figure object called fig using plt.figure()**
# -**Use add_axes to add an axis to the figure canvas at [0,0,0.8,0.8]. Call this new axis ax.**
# -**Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,0.8,0.8])
ax.plot(x, y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Matplotlib example')
plt.show()

# %%
# Question 2

# %% [markdown]
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,0.8,0.8] and [0.5,0.2,.2,.2] respectively.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 0.8, 0.8])
ax2 = fig.add_axes([0.5, 0.2, 0.2, 0.2])
plt.show()

# %%
# Question 3

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 0.8, 0.8])
ax2 = fig.add_axes([0.5, 0.2, 0.2, 0.2])
ax1.plot(x, y)
ax2.plot(x, y)
plt.show()

# %%
# Question 4

# %% [markdown]
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x, y, color='blue', linewidth=2, linestyle='--')
axes[0].set_title("x vs y")

axes[1].plot(x, z, color='red', linewidth=3, linestyle='-')
axes[1].set_title("x vs z")

plt.show()

# %%
# Question 5

# %% [markdown]
# **Resize the plot by adding the 'figsize = (12,2)' argument in plt.subplots()**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 2))
axes[0].plot(x, y, color='blue', linewidth=2, linestyle='--')
axes[0].set_title("x vs y")

axes[1].plot(x, z, color='red', linewidth=3, linestyle='-')
axes[1].set_title("x vs z")

plt.show()

# %% [markdown]
# # HW2 - Seaborn Exercises - Sol
#
# Maximum Number of Points: 10 (2 points per question)

# %% [markdown]
# ## The Data
#
# You will be working with a famous titanic data set for these exercises. In later lectures, we will revisit this data, and use it to predict survival rates of passengers. For now, just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# **Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution.**
#
# ***Note: In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot.***

# %%
# Question 1
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE

# %%
sns.jointplot(x='fare', y='age', data=titanic)
plt.show()

# %%
# Question 2
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE

# %%
sns.displot(titanic['fare'], color='red', bins=30)
plt.show()

# %%
# Question 3
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE

# %%
sns.boxplot(x='class', y='age', data=titanic, palette='rainbow')
plt.show()
# Out:
# /var/folders/9t/_wb01y790cj92w3rqspqcb9w0000gn/T/ipykernel_14885/2430449539.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class', y='age', data=titanic, palette='rainbow')

# %%
# Question 4
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE

# %%
sns.swarmplot(x='class', y='age', data=titanic, palette='Set2')
plt.show()
# Out:
# /var/folders/9t/_wb01y790cj92w3rqspqcb9w0000gn/T/ipykernel_14885/4179809932.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='class', y='age', data=titanic, palette='Set2')
# /Users/rik/Downloads/Homework 2/.venv/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Question 5
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE

# %%
sns.countplot(x='sex', data=titanic, palette='Set2')
plt.show()
# Out:
# /var/folders/9t/_wb01y790cj92w3rqspqcb9w0000gn/T/ipykernel_14885/2453587246.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=titanic, palette='Set2')

# %% [markdown]
# # HW2 - Linear Regression Exercise - Sol
#
# Maximum Number of points: 50
#
# Questions 1-21 (2 points per question) - Question 22 (8 points)
#
# An Ecommerce company sells clothing online but they also have in-store style and clothing advice sessions. Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want.
# The company is trying to decide whether to focus their efforts on their mobile app experience or their website.
#
# Complete the steps below to analyze the customer data (it's fake ... not real credit card numbers or emails).

# %%
# %matplotlib inline

# %% [markdown]
# **1. Import pandas, numpy, matplotlib,and seaborn.**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get the Data
#
# The Ecommerce Customers csv file from the company has Customer info, such as Email, Address, and their color Avatar.
# It also has numerical value columns:
#
# * Avg. Session Length: Average session of in-store style advice sessions.
# * Time on App: Average time spent on App in minutes
# * Time on Website: Average time spent on Website in minutes
# * Length of Membership: How many years the customer has been a member.
# * Yearly Amount Spent: The average annual customer spending.
#
# **2. Read in the Ecommerce Customers.csv file as a DataFrame called customers.**

# %%
customers = pd.read_csv("HW2_Ecommerce Customers.csv")

# %% [markdown]
# **3. Check the head of customers, and examine it using info and describe methods.**

# %%
customers.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505
# 3           581.852344
# 4           599.406092

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
customers.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %% [markdown]
# ## Exploratory Data Analysis
#
# For the rest of the exercise only the numerical data of the csv file will be used.
#
# **4. Use seaborn to create a jointplot to compare the 'Time on Website' and 'Yearly Amount Spent' columns.**

# %%
sns.jointplot(x='Time on Website', y='Yearly Amount Spent', data=customers)
plt.show()

# %% [markdown]
# **5. Do 'Time on Website' and 'Yearly Amount Spent' look positively correlated, negatively correlated, or not correlated?**

# %%
# Write here your answer to Question 5.
# There appears to be no correlation between time spent on website and yearly amount spent.

# %% [markdown]
# **6. Do the same with the 'Time on App' column.**

# %%
sns.jointplot(x='Time on App', y='Yearly Amount Spent', data=customers)
plt.show()

# %% [markdown]
# **7. Do 'Time on App' and 'Yearly Amount Spent' look positively correlated, negatively correlated, or not correlated?**

# %%
# Write here your answer to Question 7.
# There appears to be a positive correlation between time spent on app and yearly amount spent.

# %% [markdown]
# **8. Use jointplot to create a 2D hex bin plot comparing 'Time on App' and 'Length of Membership'.**

# %%
sns.jointplot(x='Time on App', y='Length of Membership', data=customers, kind='hex')
plt.show()

# %% [markdown]
# **9. Explore the relationships across the entire data set. Use pairplot
# to recreate the plot below**
# (Depending on the speed of your computer, this may take a short while because of all the required calculations)

# %%
sns.pairplot(customers)
plt.show()

# %% [markdown]
# **10. Based off this plot what looks to be the most correlated feature with Yearly Amount Spent?**

# %%
# Write here your answer to Question 10.
# Length of Membership appears to be the most correlated feature with Yearly Amount Spent.

# %% [markdown]
# **11. Use heatmap to recreate the plot below**

# %%
numeric_cols = ['Avg. Session Length', 'Time on App', 
                'Time on Website', 'Length of Membership', 
                'Yearly Amount Spent']

df_numeric = customers[numeric_cols]
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **12. Create a linear model plot (using seaborn's lmplot) of 'Yearly Amount Spent' vs. 'Length of Membership'.**

# %%
sns.lmplot(x='Length of Membership', y='Yearly Amount Spent', data=customers)
plt.show()

# %% [markdown]
# ## Training and Testing Data
#
# **Set a variable X equal to the numerical features of the customers**

# %%
X = customers[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]
X.head()
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308

# %% [markdown]
# **13. Set a variable y equal to the "Yearly Amount Spent" column.**

# %%
Y = customers['Yearly Amount Spent']
Y.head()
# Out:
# 0    587.951054
# 1    392.204933
# 2    487.547505
# 3    581.852344
# 4    599.406092
# Name: Yearly Amount Spent, dtype: float64

# %% [markdown]
# **14. Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size=0.3 and random_state=101**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=101)

# %% [markdown]
# ## Train the Model on the training data
#
# **Import LinearRegression from sklearn.linear_model**

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **15. Create an instance of a LinearRegression model named lm.**

# %%
lm = LinearRegression()

# %% [markdown]
# **16. Train/fit lm on the training data.**

# %%
lm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **17. Print out the coefficients of the model**

# %%
print("Coefficients:", lm.coef_)
# Out:
# Coefficients: [25.98154972 38.59015875  0.19040528 61.27909654]

# %% [markdown]
# ## Evaluate model performance by predicting off the test values
#
# **18. Use lm.predict() to predict off the X_test set of the data.**

# %%
predictions = lm.predict(X_test)
predictions
# Out:
# array([456.44186104, 402.72005312, 409.2531539 , 591.4310343 ,
#        590.01437275, 548.82396607, 577.59737969, 715.44428115,
#        473.7893446 , 545.9211364 , 337.8580314 , 500.38506697,
#        552.93478041, 409.6038964 , 765.52590754, 545.83973731,
#        693.25969124, 507.32416226, 573.10533175, 573.2076631 ,
#        397.44989709, 555.0985107 , 458.19868141, 482.66899911,
#        559.2655959 , 413.00946082, 532.25727408, 377.65464817,
#        535.0209653 , 447.80070905, 595.54339577, 667.14347072,
#        511.96042791, 573.30433971, 505.02260887, 565.30254655,
#        460.38785393, 449.74727868, 422.87193429, 456.55615271,
#        598.10493696, 449.64517443, 615.34948995, 511.88078685,
#        504.37568058, 515.95249276, 568.64597718, 551.61444684,
#        356.5552241 , 464.9759817 , 481.66007708, 534.2220025 ,
#        256.28674001, 505.30810714, 520.01844434, 315.0298707 ,
#        501.98080155, 387.03842642, 472.97419543, 432.8704675 ,
#        539.79082198, 590.03070739, 752.86997652, 558.27858232,
#        523.71988382, 431.77690078, 425.38411902, 518.75571466,
#        641.9667215 , 481.84855126, 549.69830187, 380.93738919,
#        555.18178277, 403.43054276, 472.52458887, 501.82927633,
#        473.5561656 , 456.76720365, 554.74980563, 702.96835044,
#        534.68884588, 619.18843136, 500.11974127, 559.43899225,
#        574.8730604 , 505.09183544, 529.9537559 , 479.20749452,
#        424.78407899, 452.20986599, 525.74178343, 556.60674724,
#        425.7142882 , 588.8473985 , 490.77053065, 562.56866231,
#        495.75782933, 445.17937217, 456.64011682, 537.98437395,
#        367.06451757, 421.12767301, 551.59651363, 528.26019754,
#        493.47639211, 495.28105313, 519.81827269, 461.15666582,
#        528.8711677 , 442.89818166, 543.20201646, 350.07871481,
#        401.49148567, 606.87291134, 577.04816561, 524.50431281,
#        554.11225704, 507.93347015, 505.35674292, 371.65146821,
#        342.37232987, 634.43998975, 523.46931378, 532.7831345 ,
#        574.59948331, 435.57455636, 599.92586678, 487.24017405,
#        457.66383406, 425.25959495, 331.81731213, 443.70458331,
#        563.47279005, 466.14764208, 463.51837671, 381.29445432,
#        411.88795623, 473.48087683, 573.31745784, 417.55430913,
#        543.50149858, 547.81091537, 547.62977348, 450.99057409,
#        561.50896321, 478.30076589, 484.41029555, 457.59099941,
#        411.52657592, 375.47900638])

# %% [markdown]
# **19. Create a scatterplot of the real test values versus the predicted values.**

# %%
plt.scatter(Y_test, predictions)
plt.xlabel("Y Test")
plt.ylabel("Predicted Y")
plt.show()

# %% [markdown]
# **Import the [metrics](https://scikit-learn.org/stable/modules/model_evaluation.html) module form sklearn**

# %%
from sklearn import metrics

# %% [markdown]
# **19. Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error.**

# %%
print("MAE:", metrics.mean_absolute_error(Y_test, predictions))
print("MSE:", metrics.mean_squared_error(Y_test, predictions))
print("RMSE:", np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
# Out:
# MAE: 7.228148653430839
# MSE: 79.8130516509746
# RMSE: 8.933815066978642

# %% [markdown]
# **20. Calculate R-squared (percentage of explained variance)**

# %%
print("R-squared:", lm.score(X_test, Y_test))
# Out:
# R-squared: 0.9890046246741234

# %% [markdown]
# **21. Do you think the company should focus more on their mobile app or on their website? Write your thoughts**

# %%
# Write here your answer to Question 21.
# There appears to be a positive correlation between time spent on app and yearly amount spent, whereas
# there appears to be no correlation between time spent on website and yearly amount spent. Therefore,
# focusing on improving the app experience would likely be more beneficial for increasing yearly amount spent.

# %% [markdown]
# **22. Open Question: Imagine client asked: are there other insights from this data. Do addtional analysis, pick two insights and prove your claims. (8 points)**

# %%
# Write here your answer to Question 22.
# The coefficients indicate the change in yearly amount spent for a one unit increase in each feature,
# holding all other features constant. For example, a one unit increase in Time on App is associated with
# an increase of approximately $38.59 in yearly amount spent, while a one unit increase in length of membership
# is associated with an increase of approximately $61.27 in yearly amount spent. This suggests that length of membership
# has a stronger impact on yearly amount spent compared to time on app, time on website, and average session length.

# %% [markdown]
# # Logistic Regression Exercise
#
# Maximum Number of points: 30
#
# Questions 1-15 (2 points per question)
#
# You will be working with a fake advertising data set, indicating whether or not a particular internet user clicked on an advertisement on a company website.
# The task is to create a model to predict whether or not a user will click on an ad based off the features of that user.
#
# This data set contains the following features:
#
# * 'Daily Time Spent on Site': consumer time on site in minutes
# * 'Age': cutomer age in years
# * 'Area Income': Avg. Income of geographical area of consumer
# * 'Daily Internet Usage': Avg. minutes a day consumer is on the internet
# * 'Ad Topic Line': Headline of the advertisement
# * 'City': City of consumer
# * 'Male': Whether or not consumer was male
# * 'Country': Country of consumer
# * 'Timestamp': Time at which consumer clicked on Ad or closed window
# * 'Clicked on Ad': 0 or 1 indicated clicking on Ad

# %% [markdown]
# ## Import Libraries
#
# **Import the libraries you will need**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Get the Data
# **1. Read in the advertising.csv file and set it to a data frame called ad_data.**

# %%
ad_data = pd.read_csv("HW2_advertising.csv")

# %% [markdown]
# **2. Check the head of ad_data**

# %%
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# 1  2016-04-04 01:39:02              0
# 2  2016-03-13 20:35:42              0
# 3  2016-01-10 02:31:19              0
# 4  2016-06-03 03:36:18              0

# %% [markdown]
# **3. Use info and describe on ad_data**

# %%
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.3+ KB

# %%
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# 75%              218.792500     1.000000        1.00000
# max              269.960000     1.000000        1.00000

# %% [markdown]
# ## Exploratory Data Analysis
#
# Use seaborn to explore the data.

# %% [markdown]
# **4. Create a histogram of the Age**

# %%
sns.histplot(ad_data['Age'], bins=30, kde=False)
plt.show()

# %% [markdown]
# **5. Create a jointplot showing Area Income versus Age.**

# %%
sns.jointplot(x='Age', y='Area Income', data=ad_data)
plt.show()

# %% [markdown]
# **6. Create a jointplot showing the kde distributions of Daily Time spent on site vs. Age.**

# %%
sns.jointplot(x='Age', y='Daily Time Spent on Site',
              data=ad_data, kind='kde', color='red')
plt.show()

# %% [markdown]
# **7. Create a jointplot showing scatter plot of 'Daily Time Spent on Site' vs. 'Daily Internet Usage'**

# %%
sns.jointplot(x='Daily Time Spent on Site',
              y='Daily Internet Usage', data=ad_data, color='green')
plt.show()

# %% [markdown]
# **8. Create a pairplot with the hue defined by the 'Clicked on Ad' column feature.**

# %%
sns.pairplot(ad_data, hue='Clicked on Ad')
plt.show()

# %% [markdown]
# # Logistic Regression
#
# Create, train, and test a model using different features. We want to experiment to find the features that lead to the best model.

# %% [markdown]
# **9. Split the data into training set (with 'Daily Time Spent on Site' and 'Daily Internet Usage' as the only features) and testing set using 'train_test_split' with 'random_state' set to 101.**

# %%
from sklearn.model_selection import train_test_split

# %%
X = ad_data[['Daily Time Spent on Site', 'Daily Internet Usage']]
y = ad_data['Clicked on Ad']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=101)

# %% [markdown]
# **10. Train and fit a logistic regression model on the training set.**

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Out:
# LogisticRegression()

# %% [markdown]
# ## Predictions and Evaluations
# **11. Predict values for the testing data.**

# %%
predictions = logmodel.predict(X_test)

# %% [markdown]
# **12. Create a confusion_matrix for the model.**

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[153   4]
#  [ 10 133]]

# %% [markdown]
# **13. Create a classification report for the model.**

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       157
#            1       0.97      0.93      0.95       143
#
#     accuracy                           0.95       300
#    macro avg       0.95      0.95      0.95       300
# weighted avg       0.95      0.95      0.95       300

# %% [markdown]
# **14. Retrain your model on a new training set with 'Age' and 'Daily Internet Usage' as the only features and re-do the confusion matrix.**

# %%
X = ad_data[['Age', 'Daily Internet Usage']]
y = ad_data['Clicked on Ad']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=101)

# %%
logmodel2 = LogisticRegression()
logmodel2.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Out:
# LogisticRegression()

# %%
predictions2 = logmodel2.predict(X_test)

# %%
print(confusion_matrix(y_test, predictions2))
# Out:
# [[146  11]
#  [ 17 126]]

# %% [markdown]
# **15. Are the results in Question 14 better or worse than before? Why? **

# %%
# Write your answer here.
# The model using Age and Daily Internet Usage performs slightly worse than the model using Daily Time Spent on Site and Daily Internet Usage.
# The number of false positives increased from 4 to 11, and the number of false negatives increased from 10 to 17. Therefore, the model accuracy decreased.
